# %% [markdown]
# ### 1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 621    618000.0  2012
# 622   6050000.0  2012
# 623    838000.0  2012
# 624   8487000.0  2012
# 625   4769000.0  2012
#
# [626 rows x 8 columns]

# %% [markdown]
# ### 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %% [markdown]
# ### 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
# Group the data by year and calculate the sum of each column for each year
yearly_data = df.groupby('year').sum()

# Plot the pie chart
yearly_data.plot.pie(y='totalprod', figsize=(10, 10), autopct='%1.1f%%')
plt.title('Percentage Distribution of Total Honey Production by Year')
plt.ylabel('totalprod')
plt.show()

# %% [markdown]
# ### 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data = df, x = df['priceperlb'], kind = 'kde')
plt.title('Distribution of the variable price per lb')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Distribution of the variable price per lb')

# %% [markdown]
# ### 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
df['prodvalue']
# Out:
# 0        818000.0
# 1       2112000.0
# 2       2033000.0
# 3      23157000.0
# 4       1361000.0
#           ...
# 621      618000.0
# 622     6050000.0
# 623      838000.0
# 624     8487000.0
# 625     4769000.0
# Name: prodvalue, Length: 626, dtype: float64

# %%
plt.figure(figsize = (25,10))
sns.scatterplot(df, x = 'numcol', y = 'prodvalue')
plt.title('Relationship between numcol and prodvalue')
plt.show()

# %% [markdown]
# - It represents the positive good relationship between numcol and prodvalue

# %% [markdown]
# ### 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize = (25,10))
sns.boxplot(df, x = 'year', y = 'prodvalue')
plt.title('Boxplot of prodvalue by year')
plt.show()

# %% [markdown]
# - In the year 2010 and 2012 has the high positive outliers belongs to prodvalue.
# - This Boxplot represents the no negative outliers present in this variable prodvalue
# - Over the year the outliers are minimum in the initial stage and maximum in the end of the period

# %% [markdown]
# ### 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
cols = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']
cols
sns.pairplot(df[cols])
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol','total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
cols = [ 'numcol', 'yieldpercol','totalprod', 'stocks', 'priceperlb', 'prodvalue']
cols
sns.heatmap(df[cols].corr(),annot = True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# - In this Heat Map numcol and totalprod are high positive correlated variables with 95%
# - And prodvalue with numcol and totalprod has the good relation between them with 91% positively correlated
# - priceperlb has the strong negative correlated with all other variables
